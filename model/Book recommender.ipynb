# %%
import pandas as pd
import numpy as np

# %%
#data
"https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset"

books=pd.read_csv("Books.csv")
ratings=pd.read_csv('Ratings.csv')
users=pd.read_csv('Users.csv')
# Out:
# C:\Users\ankit\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3194: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
print(books.duplicated().sum())
print(ratings.duplicated().sum())
print(users.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## Popularity base sys

# %%
ratings_new =ratings.merge(books,on='ISBN')

# %%
num_of_rating=ratings_new.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_of_rating.rename(columns={'Book-Rating':'num_rating'},inplace=True)
num_of_rating.head()
# Out:
#                                           Book-Title  num_rating
# 0   A Light in the Storm: The Civil War Diary of ...           4
# 1                              Always Have Popsicles           1
# 2               Apple Magic (The Collector's series)           1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4   Beyond IBM: Leadership Marketing and Finance ...           1

# %%
avg_of_rating=ratings_new.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_of_rating.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_of_rating.head()
# Out:
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
popularity=num_of_rating.merge(avg_of_rating,on='Book-Title')

# %%
popular_df=popularity[popularity['num_rating']>=200].sort_values(by='avg_rating',ascending=False).head(50)

# %%
popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_rating','avg_rating']]

# %%
popular_df.shape
# Out:
# (50, 5)

# %% [markdown]
# ## Collabrative recommend sys

# %%
x=ratings_new.groupby('User-ID').count()['Book-Rating']>200
indexing = x[x].index

# %%
filter_data = ratings_new[ratings_new['User-ID'].isin(indexing)]

# %%
filter_data.head()
# Out:
#     User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 2      6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 5     23768  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 7     28523  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 15    77940  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 16    81977  034545104X            0  Flesh Tones: A Novel  M. J. Rose
#
#    Year-Of-Publication         Publisher  \
# 2                 2002  Ballantine Books
# 5                 2002  Ballantine Books
# 7                 2002  Ballantine Books
# 15                2002  Ballantine Books
# 16                2002  Ballantine Books
#
#                                           Image-URL-S  \
# 2   http://images.amazon.com/images/P/034545104X.0...
# 5   http://images.amazon.com/images/P/034545104X.0...
# 7   http://images.amazon.com/images/P/034545104X.0...
# 15  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
y=filter_data.groupby('Book-Title').count()['Book-Rating']>=50
indexing1=y[y].index

# %%
final_rating=filter_data[filter_data['Book-Title'].isin(indexing1)]

# %%
final_rating.head()
# Out:
#     User-ID        ISBN  Book-Rating    Book-Title      Book-Author  \
# 63   278418  0446520802            0  The Notebook  Nicholas Sparks
# 65     3363  0446520802            0  The Notebook  Nicholas Sparks
# 66     7158  0446520802           10  The Notebook  Nicholas Sparks
# 69    11676  0446520802           10  The Notebook  Nicholas Sparks
# 74    23768  0446520802            6  The Notebook  Nicholas Sparks
#
#    Year-Of-Publication     Publisher  \
# 63                1996  Warner Books
# 65                1996  Warner Books
# 66                1996  Warner Books
# 69                1996  Warner Books
# 74                1996  Warner Books
#
#                                           Image-URL-S  \
# 63  http://images.amazon.com/images/P/0446520802.0...
# 65  http://images.amazon.com/images/P/0446520802.0...
# 66  http://images.amazon.com/images/P/0446520802.0...
# 69  http://images.amazon.com/images/P/0446520802.0...
# ...

# %%
pt=final_rating.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(pt)
# Out:
# C:\Users\ankit\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
def recommend1(book_name):
    #sugessions=[]
    index = np.where(pt.index==book_name)[0][0]
    similar_list = sorted(list(enumerate(similarity[index])),key=lambda x:x[1],reverse=True)[1:6]
    data=[]
    for i in similar_list:
        data.append(pt.index[i[0]])
    return data

# %%
def recommend(book_name):
    #sugessions=[]
    index = np.where(pt.index==book_name)[0][0]
    similar_list = sorted(list(enumerate(similarity[index])),key=lambda x:x[1],reverse=True)[1:6]
    data=[]
    for i in similar_list:
        item=[]
        temp = books[books['Book-Title']==pt.index[i[0]]]
        item.extend(list(temp.drop_duplicates('Book-Title')['Book-Title']))
        item.extend(list(temp.drop_duplicates('Book-Title')['Book-Author']))
        item.extend(list(temp.drop_duplicates('Book-Title')['Image-URL-M']))
        data.append(item)
    return data

# %%
recommend('1984')[0]
# Out:
# ['Animal Farm',
#  'George Orwell',
#  'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg']

# %%
recommend1('1984')
# Out:
# ['Animal Farm',
#  "The Handmaid's Tale",
#  'Brave New World',
#  'The Vampire Lestat (Vampire Chronicles, Book II)',
#  'The Hours : A Novel']

# %%
recommend('You Belong To Me')
# Out:
# ['Loves Music, Loves to Dance',
#  "I'll Be Seeing You",
#  'Before I Say Good-Bye',
#  "Daddy's Little Girl",
#  'All Around the Town']

# %%
import pickle
pickle.dump(popular_df,open('popular_df.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
